# %% [markdown]
# # Training Iteration 2
#
# - Big breakthrough was that RMSProp with lr=1e-3 was way, way better than lr=1e-4
# - Removed blur from augmentation and generally decreased others
# - Also switched to ELU activation in conv blocks

# %%
# %run ../utils.py
# %run models.py
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os
import os.path as osp
import pickle
import matplotlib.pyplot as plt
from cvutils import visualize
from imgaug import augmenters as iaa
import imgaug as ia
from cvutils.keras import generator as keras_generator
from cvutils.augmentation import imgaug as imgaug_utils
from codex_ml import losses
from codex_ml import augmentation as augmentation_pipelines
import pandas as pd
seed = 8932
plt.gray()
init_session()

train_image_dir = osp.join(os.environ['CODEX_DATA_DIR'], 'modeling', 'cytopy', 'datasets', 'kdsb2018', 'stage1_train')
data_dir = osp.join(os.environ['CODEX_DATA_DIR'], 'modeling', 'cytopy', 'datasets', 'kdsb2018', 'prep')
data_file = 'training_data_03.pkl' # crop resizing, shrunken markers
model_dir = osp.join(os.environ['CODEX_DATA_DIR'], 'modeling', 'cytopy', 'models', 'nuclei', 'v0.1')
model_path = osp.join(model_dir, 'nuclei_model.h5')

# %%
with open(osp.join(data_dir, data_file), 'rb') as fd:
    data = pickle.load(fd)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'class_names', 'Y', 'X', 'index'])

# %%
X, Y, class_names, index, meta = [data[k] for k in ['X', 'Y', 'class_names', 'index', 'meta']]

# %%
X.shape, X.dtype, Y.shape, Y.dtype, index.shape
# Out:
# ((1752, 256, 256, 1),
#  dtype('uint8'),
#  (1752, 256, 256, 5),
#  dtype('bool'),
#  (1752,))

# %%
input_shape = X.shape[1:]
input_shape
# Out:
# (256, 256, 1)

# %%
class_names
# Out:
# ['bg', 'nuc_interior', 'nuc_boundary', 'nuc_partition', 'nuc_center']

# %%
# Determine percent coverage of background in each image
bg_pcts = pd.Series([Y[i, ..., class_names.index('bg')].mean() for i in range(Y.shape[0])])
bg_pcts.hist(bins=128)

# %%
bg_mask = ((bg_pcts > .5) & (bg_pcts < 1.)).values
X, Y, index = X[bg_mask], Y[bg_mask], index[bg_mask]
X.shape, Y.shape, index.shape
# Out:
# ((1091, 256, 256, 1), (1091, 256, 256, 5), (1091,))

# %%
visualize.display_images([X[i, ..., 0] for i in range(0, 8)], size=12)

# %%
visualize.display_images([Y[2, ..., i] for i in range(Y.shape[-1])], cols=len(class_names), titles=class_names, size=24)

# %%
# Determine frequency of positive pixels by mask class
class_freq = np.apply_over_axes(np.mean, Y, axes=[0, 1, 2]).squeeze()
class_freq = pd.Series(dict(zip(class_names, class_freq)))
class_freq
# Out:
# bg               0.816516
# nuc_boundary     0.018195
# nuc_center       0.071726
# nuc_interior     0.118800
# nuc_partition    0.002741
# dtype: float64

# %%
1/class_freq
# Out:
# bg                 1.224715
# nuc_boundary      54.960932
# nuc_center        13.941878
# nuc_interior       8.417475
# nuc_partition    364.815250
# dtype: float64

# %%
# train_classes = ['nuc_interior', 'nuc_boundary', 'nuc_partition', 'nuc_center']
# train_class_wt = [1., 10., 50., 50.]
train_classes = ['nuc_interior', 'nuc_partition', 'nuc_center']

train_class_wt = [1., 30., 5.]

# pos_importance_factor = 50.
# train_class_wt = 1. / class_freq.loc[train_classes]
# train_class_wt /= train_class_wt.sum()
# train_class_wt = (pos_importance_factor * train_class_wt).round(2).tolist()

train_classes_idx = [class_names.index(c) for c in train_classes]
batch_size = 32

assert len(train_class_wt) == len(train_classes)
n_classes = len(train_classes)
Y_target = Y[..., train_classes_idx]
Y.shape, Y_target.shape, train_class_wt
# Out:
# ((1091, 256, 256, 5), (1091, 256, 256, 3), [1.0, 30.0, 5.0])

# %%
from sklearn.model_selection import train_test_split
idx_train, idx_test = train_test_split(np.arange(X.shape[0]), test_size=.2, random_state=seed)
X_train, X_test, Y_train, Y_test = X[idx_train], X[idx_test], Y_target[idx_train], Y_target[idx_test]

# X_train = X_train[:(batch_size * 8)]
# Y_train = Y_train[:(batch_size * 8)]

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((872, 256, 256, 1),
#  (219, 256, 256, 1),
#  (872, 256, 256, 3),
#  (219, 256, 256, 3))

# %%
X_train_moments = dict(mean=X_train.mean(), std=X_train.std())
X_train_moments
# Out:
# {'mean': 22.95665170512068, 'std': 39.01833230843019}

# %%
# %run models.py
opt_conv = {"activation": "elu", "padding": "same", 'kernel_initializer': 'he_normal'}
#model = get_model(n_classes, input_shape, activation='sigmoid', p=[6,7,8,9], batch_norm=True, dropout=None)

model = get_model(n_classes, input_shape, activation='sigmoid', p=[4,5,6,7,8], batch_norm=True, dropout=None, opt_conv=opt_conv)

#model = get_model(n_classes, input_shape, activation='sigmoid', p=[4,5,6,7,8], batch_norm=True, dropout=None)
#model = get_model(n_classes, input_shape, activation='sigmoid', p=[4,5,6,7,8], batch_norm=False, dropout=[.1,.1,.2,.2,.3])
#model = get_model(n_classes, input_shape, activation='sigmoid', p=[4,5,6,7,8], batch_norm=False, dropout=[.1,.1,.2,.2,.3])

#model = get_model(n_classes, input_shape, activation='sigmoid', p=[6,7,8,9], batch_norm=True, dropout=None)

# %%
optimizer = keras.optimizers.RMSprop(lr=1e-3)
metrics = [keras.metrics.binary_accuracy]
loss = losses.objective_weighted_binary_crossentropy([[train_class_wt]])

for i, c in enumerate(train_classes):
    metrics.append(binary_channel_precision(i, c, min_p=.6))
model.compile(loss=loss, metrics=metrics, optimizer=optimizer)

# %%
import imp
imp.reload(augmentation_pipelines)
augmentation = augmentation_pipelines.get_augmentation_pipeline_01()

# %%
# visualize_augmentation(list(load_images(train_image_dir).values())[0], augmentation, 11, cols=4, size=20)

# %%
imp.reload(imgaug_utils)
# Out:
# <module 'cvutils.augmentation.imgaug' from '/lab/repos/cvutils/python/cvutils/augmentation/imgaug.py'>

# %%
def pre_network_processor(sample_id, X, Y):
    # Convert image to standardized floats for network
    assert X.dtype == np.uint8
    assert Y.dtype == np.bool
    
    X = X.astype(np.float32)
    X = (X - X_train_moments['mean']) / X_train_moments['std']
    Y = Y.astype(np.float32)
    return X, Y

train_loader = imgaug_utils.InMemoryDataLoader(X_train, Y_train, augmentation=augmentation, processor=pre_network_processor)
test_loader = imgaug_utils.InMemoryDataLoader(X_test, Y_test, augmentation=None, processor=pre_network_processor)

train_generator = keras_generator.BaseDataGenerator(train_loader.ids, train_loader.load, batch_size=batch_size, shuffle=True)
test_generator = keras_generator.BaseDataGenerator(test_loader.ids, test_loader.load, batch_size=batch_size, shuffle=True)

# %%
# ex_aug = 'ex2'
# visualize_segmentation_augmentation(
#     X[index == DEFAULT_IDS[ex_aug]][0],
#     Y_target[index == DEFAULT_IDS[ex_aug]][0],
#     augmentation, n=5, size=30
# )

# %%
# !rm $model_dir/* || true

callbacks = [
    keras.callbacks.ModelCheckpoint(
        model_path, monitor='val_loss', mode='min', verbose=0, 
        save_best_only=True, save_weights_only=False, period=1
    ), 
    keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=6, verbose=0, mode='min'), 
    keras.callbacks.TensorBoard(log_dir=model_dir),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, mode='min')
]

history = model.fit_generator(
    train_generator, 
    epochs=75,
    #steps_per_epoch=15,
    callbacks=callbacks,
    validation_data=test_generator
)
# Out:
# Epoch 1/75
# 27/27 [==============================] - 11s 404ms/step - loss: 0.7462 - binary_accuracy: 0.7604 - nuc_interior: 0.6076 - nuc_partition: 0.0645 - nuc_center: 0.4154 - val_loss: 0.5782 - val_binary_accuracy: 0.9027 - val_nuc_interior: 0.8151 - val_nuc_partition: 0.0141 - val_nuc_center: 0.5529
# Epoch 2/75
# 27/27 [==============================] - 7s 277ms/step - loss: 0.6487 - binary_accuracy: 0.8598 - nuc_interior: 0.7796 - nuc_partition: 0.0823 - nuc_center: 0.5526 - val_loss: 0.5644 - val_binary_accuracy: 0.9230 - val_nuc_interior: 0.9382 - val_nuc_partition: 0.0147 - val_nuc_center: 0.6986
# Epoch 3/75
# 27/27 [==============================] - 9s 319ms/step - loss: 0.6012 - binary_accuracy: 0.8924 - nuc_interior: 0.8301 - nuc_partition: 0.1234 - nuc_center: 0.6175 - val_loss: 0.4753 - val_binary_accuracy: 0.9533 - val_nuc_interior: 0.9243 - val_nuc_partition: 0.0180 - val_nuc_center: 0.7057
# Epoch 4/75
# 27/27 [==============================] - 9s 348ms/step - loss: 0.5600 - binary_accuracy: 0.9156 - nuc_interior: 0.8623 - nuc_partition: 0.1477 - nuc_center: 0.6574 - val_loss: 0.4818 - val_binary_accuracy: 0.9418 - val_nuc_interior: 0.8948 - val_nuc_partition: 0.0197 - val_nuc_center: 0.7073
# Epoch 5/75
# 27/27 [==============================] - 9s 330ms/step - loss: 0.5465 - binary_accuracy: 0.9281 - nuc_interior: 0.8704 - nuc_partition: 0.1877 - nuc_center: 0.6805 - val_loss: 0.4614 - val_binary_accuracy: 0.9630 - val_nuc_interior: 0.9594 - val_nuc_partition: 0.0369 - val_nuc_center: 0.7848
# Epoch 6/75
# 27/27 [==============================] - 9s 330ms/step - loss: 0.5121 - binary_accuracy: 0.9415 - nuc_interior: 0.8911 - nuc_partition: 0.2439 - nuc_center: 0.7141 - val_loss: 0.4504 - val_binary_accuracy: 0.9690 - val_nuc_interior: 0.9225 - val_nuc_partition: 0.0484 - val_nuc_center: 0.7009
# Epoch 7/75
# 27/27 [==============================] - 9s 339ms/step - loss: 0.4907 - binary_accuracy: 0.9478 - nuc_interior: 0.9058 - nuc_partition: 0.2923 - nuc_center: 0.7286 - val_loss: 0.4192 - val_binary_accuracy: 0.9700 - val_nuc_interior: 0.9472 - val_nuc_partition: 0.0482 - val_nuc_center: 0.7603
# Epoch 8/75
# 27/27 [==============================] - 9s 348ms/step - loss: 0.4712 - binary_accuracy: 0.9539 - nuc_interior: 0.9141 - nuc_partition: 0.2899 - nuc_center: 0.7416 - val_loss: 0.3981 - val_binary_accuracy: 0.9781 - val_nuc_interior: 0.9452 - val_nuc_partition: 0.0819 - val_nuc_center: 0.7812
# Epoch 9/75
# 27/27 [==============================] - 8s 307ms/step - loss: 0.4640 - binary_accuracy: 0.9552 - nuc_interior: 0.9161 - nuc_partition: 0.2956 - nuc_center: 0.7565 - val_loss: 0.4033 - val_binary_accuracy: 0.9672 - val_nuc_interior: 0.9659 - val_nuc_partition: 0.0453 - val_nuc_center: 0.8494
# Epoch 10/75
# 27/27 [==============================] - 9s 336ms/step - loss: 0.4420 - binary_accuracy: 0.9621 - nuc_interior: 0.9239 - nuc_partition: 0.3330 - nuc_center: 0.7710 - val_loss: 0.4173 - val_binary_accuracy: 0.9737 - val_nuc_interior: 0.8907 - val_nuc_partition: 0.0711 - val_nuc_center: 0.7253
# Epoch 11/75
# 27/27 [==============================] - 8s 311ms/step - loss: 0.4333 - binary_accuracy: 0.9619 - nuc_interior: 0.9269 - nuc_partition: 0.3539 - nuc_center: 0.7723 - val_loss: 0.3903 - val_binary_accuracy: 0.9775 - val_nuc_interior: 0.9709 - val_nuc_partition: 0.0771 - val_nuc_center: 0.8697
# Epoch 12/75
# 27/27 [==============================] - 9s 335ms/step - loss: 0.4266 - binary_accuracy: 0.9636 - nuc_interior: 0.9316 - nuc_partition: 0.3714 - nuc_center: 0.7818 - val_loss: 0.3672 - val_binary_accuracy: 0.9831 - val_nuc_interior: 0.9645 - val_nuc_partition: 0.1282 - val_nuc_center: 0.8331
# Epoch 13/75
# 27/27 [==============================] - 10s 352ms/step - loss: 0.4111 - binary_accuracy: 0.9686 - nuc_interior: 0.9377 - nuc_partition: 0.3945 - nuc_center: 0.7938 - val_loss: 0.3675 - val_binary_accuracy: 0.9838 - val_nuc_interior: 0.9652 - val_nuc_partition: 0.1405 - val_nuc_center: 0.8664
# Epoch 14/75
# 27/27 [==============================] - 8s 310ms/step - loss: 0.4099 - binary_accuracy: 0.9663 - nuc_interior: 0.9362 - nuc_partition: 0.4019 - nuc_center: 0.7948 - val_loss: 0.3647 - val_binary_accuracy: 0.9768 - val_nuc_interior: 0.9382 - val_nuc_partition: 0.0902 - val_nuc_center: 0.7557
# Epoch 15/75
# 27/27 [==============================] - 9s 318ms/step - loss: 0.4031 - binary_accuracy: 0.9680 - nuc_interior: 0.9401 - nuc_partition: 0.4164 - nuc_center: 0.8038 - val_loss: 0.3913 - val_binary_accuracy: 0.9578 - val_nuc_interior: 0.9424 - val_nuc_partition: 0.0356 - val_nuc_center: 0.7400
# Epoch 16/75
# 27/27 [==============================] - 9s 319ms/step - loss: 0.4052 - binary_accuracy: 0.9690 - nuc_interior: 0.9391 - nuc_partition: 0.3862 - nuc_center: 0.7924 - val_loss: 0.3753 - val_binary_accuracy: 0.9806 - val_nuc_interior: 0.9569 - val_nuc_partition: 0.1252 - val_nuc_center: 0.8542
# Epoch 17/75
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4006 - binary_accuracy: 0.9691 - nuc_interior: 0.9372 - nuc_partition: 0.3943 - nuc_center: 0.7968 - val_loss: 0.3522 - val_binary_accuracy: 0.9817 - val_nuc_interior: 0.9623 - val_nuc_partition: 0.1076 - val_nuc_center: 0.8535
# Epoch 18/75
# 27/27 [==============================] - 8s 313ms/step - loss: 0.3939 - binary_accuracy: 0.9709 - nuc_interior: 0.9403 - nuc_partition: 0.4117 - nuc_center: 0.8037 - val_loss: 0.3468 - val_binary_accuracy: 0.9856 - val_nuc_interior: 0.9744 - val_nuc_partition: 0.1795 - val_nuc_center: 0.8740
# Epoch 19/75
# 27/27 [==============================] - 9s 351ms/step - loss: 0.3922 - binary_accuracy: 0.9713 - nuc_interior: 0.9387 - nuc_partition: 0.4260 - nuc_center: 0.8022 - val_loss: 0.3466 - val_binary_accuracy: 0.9846 - val_nuc_interior: 0.9709 - val_nuc_partition: 0.1507 - val_nuc_center: 0.8700
# Epoch 20/75
# 27/27 [==============================] - 9s 318ms/step - loss: 0.3939 - binary_accuracy: 0.9729 - nuc_interior: 0.9408 - nuc_partition: 0.4186 - nuc_center: 0.8107 - val_loss: 0.3453 - val_binary_accuracy: 0.9837 - val_nuc_interior: 0.9488 - val_nuc_partition: 0.1776 - val_nuc_center: 0.8068
# Epoch 21/75
# 27/27 [==============================] - 9s 348ms/step - loss: 0.3847 - binary_accuracy: 0.9725 - nuc_interior: 0.9378 - nuc_partition: 0.4364 - nuc_center: 0.8082 - val_loss: 0.3463 - val_binary_accuracy: 0.9842 - val_nuc_interior: 0.9783 - val_nuc_partition: 0.1456 - val_nuc_center: 0.8870
# Epoch 22/75
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3851 - binary_accuracy: 0.9728 - nuc_interior: 0.9390 - nuc_partition: 0.4380 - nuc_center: 0.8086 - val_loss: 0.3438 - val_binary_accuracy: 0.9865 - val_nuc_interior: 0.9613 - val_nuc_partition: 0.2689 - val_nuc_center: 0.8351
# Epoch 23/75
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3800 - binary_accuracy: 0.9740 - nuc_interior: 0.9410 - nuc_partition: 0.4748 - nuc_center: 0.8168 - val_loss: 0.3490 - val_binary_accuracy: 0.9861 - val_nuc_interior: 0.9717 - val_nuc_partition: 0.2040 - val_nuc_center: 0.8813
# Epoch 24/75
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3812 - binary_accuracy: 0.9744 - nuc_interior: 0.9425 - nuc_partition: 0.4521 - nuc_center: 0.8154 - val_loss: 0.3448 - val_binary_accuracy: 0.9803 - val_nuc_interior: 0.9407 - val_nuc_partition: 0.1258 - val_nuc_center: 0.7685
# Epoch 25/75
# 27/27 [==============================] - 9s 339ms/step - loss: 0.3807 - binary_accuracy: 0.9743 - nuc_interior: 0.9407 - nuc_partition: 0.4447 - nuc_center: 0.8166 - val_loss: 0.3381 - val_binary_accuracy: 0.9851 - val_nuc_interior: 0.9643 - val_nuc_partition: 0.1648 - val_nuc_center: 0.8545
# Epoch 26/75
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3972 - binary_accuracy: 0.9704 - nuc_interior: 0.9307 - nuc_partition: 0.4819 - nuc_center: 0.8040 - val_loss: 0.3449 - val_binary_accuracy: 0.9806 - val_nuc_interior: 0.9614 - val_nuc_partition: 0.0923 - val_nuc_center: 0.8332
# Epoch 27/75
# 27/27 [==============================] - 9s 317ms/step - loss: 0.3724 - binary_accuracy: 0.9762 - nuc_interior: 0.9486 - nuc_partition: 0.5065 - nuc_center: 0.8282 - val_loss: 0.3393 - val_binary_accuracy: 0.9848 - val_nuc_interior: 0.9542 - val_nuc_partition: 0.2027 - val_nuc_center: 0.8210
# Epoch 28/75
# 27/27 [==============================] - 9s 320ms/step - loss: 0.3835 - binary_accuracy: 0.9736 - nuc_interior: 0.9409 - nuc_partition: 0.4414 - nuc_center: 0.8127 - val_loss: 0.3402 - val_binary_accuracy: 0.9827 - val_nuc_interior: 0.9658 - val_nuc_partition: 0.1203 - val_nuc_center: 0.8402
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 29/75
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3764 - binary_accuracy: 0.9758 - nuc_interior: 0.9491 - nuc_partition: 0.4071 - nuc_center: 0.8170 - val_loss: 0.3390 - val_binary_accuracy: 0.9852 - val_nuc_interior: 0.9694 - val_nuc_partition: 0.1778 - val_nuc_center: 0.8623
# Epoch 30/75
# 27/27 [==============================] - 9s 333ms/step - loss: 0.3803 - binary_accuracy: 0.9764 - nuc_interior: 0.9484 - nuc_partition: 0.4922 - nuc_center: 0.8292 - val_loss: 0.3363 - val_binary_accuracy: 0.9868 - val_nuc_interior: 0.9704 - val_nuc_partition: 0.1989 - val_nuc_center: 0.8715
# Epoch 31/75
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3779 - binary_accuracy: 0.9761 - nuc_interior: 0.9457 - nuc_partition: 0.4652 - nuc_center: 0.8240 - val_loss: 0.3372 - val_binary_accuracy: 0.9861 - val_nuc_interior: 0.9704 - val_nuc_partition: 0.1938 - val_nuc_center: 0.8681
# Epoch 32/75
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3661 - binary_accuracy: 0.9774 - nuc_interior: 0.9486 - nuc_partition: 0.5155 - nuc_center: 0.8343 - val_loss: 0.3363 - val_binary_accuracy: 0.9860 - val_nuc_interior: 0.9694 - val_nuc_partition: 0.1940 - val_nuc_center: 0.8639
# Epoch 33/75
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3662 - binary_accuracy: 0.9770 - nuc_interior: 0.9450 - nuc_partition: 0.4886 - nuc_center: 0.8285 - val_loss: 0.3362 - val_binary_accuracy: 0.9858 - val_nuc_interior: 0.9700 - val_nuc_partition: 0.1935 - val_nuc_center: 0.8577
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 34/75
# 27/27 [==============================] - 9s 316ms/step - loss: 0.3753 - binary_accuracy: 0.9766 - nuc_interior: 0.9462 - nuc_partition: 0.4987 - nuc_center: 0.8252 - val_loss: 0.3350 - val_binary_accuracy: 0.9860 - val_nuc_interior: 0.9677 - val_nuc_partition: 0.1879 - val_nuc_center: 0.8580
# Epoch 35/75
# 27/27 [==============================] - 8s 311ms/step - loss: 0.3672 - binary_accuracy: 0.9770 - nuc_interior: 0.9455 - nuc_partition: 0.4317 - nuc_center: 0.8204 - val_loss: 0.3350 - val_binary_accuracy: 0.9857 - val_nuc_interior: 0.9667 - val_nuc_partition: 0.1741 - val_nuc_center: 0.8575
# Epoch 36/75
# 27/27 [==============================] - 9s 315ms/step - loss: 0.3586 - binary_accuracy: 0.9785 - nuc_interior: 0.9494 - nuc_partition: 0.4988 - nuc_center: 0.8350 - val_loss: 0.3365 - val_binary_accuracy: 0.9857 - val_nuc_interior: 0.9662 - val_nuc_partition: 0.1968 - val_nuc_center: 0.8588
# Epoch 37/75
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3645 - binary_accuracy: 0.9779 - nuc_interior: 0.9474 - nuc_partition: 0.5050 - nuc_center: 0.8316 - val_loss: 0.3364 - val_binary_accuracy: 0.9860 - val_nuc_interior: 0.9676 - val_nuc_partition: 0.1963 - val_nuc_center: 0.8615
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 38/75
# 27/27 [==============================] - 8s 312ms/step - loss: 0.3598 - binary_accuracy: 0.9784 - nuc_interior: 0.9501 - nuc_partition: 0.5440 - nuc_center: 0.8390 - val_loss: 0.3351 - val_binary_accuracy: 0.9865 - val_nuc_interior: 0.9677 - val_nuc_partition: 0.1938 - val_nuc_center: 0.8631
# Epoch 39/75
# 27/27 [==============================] - 9s 347ms/step - loss: 0.3678 - binary_accuracy: 0.9777 - nuc_interior: 0.9493 - nuc_partition: 0.5146 - nuc_center: 0.8373 - val_loss: 0.3355 - val_binary_accuracy: 0.9861 - val_nuc_interior: 0.9681 - val_nuc_partition: 0.1906 - val_nuc_center: 0.8605
# Epoch 40/75
# 27/27 [==============================] - 9s 337ms/step - loss: 0.3599 - binary_accuracy: 0.9785 - nuc_interior: 0.9510 - nuc_partition: 0.5563 - nuc_center: 0.8423 - val_loss: 0.3370 - val_binary_accuracy: 0.9859 - val_nuc_interior: 0.9706 - val_nuc_partition: 0.2029 - val_nuc_center: 0.8711
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 41/75
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3664 - binary_accuracy: 0.9777 - nuc_interior: 0.9464 - nuc_partition: 0.4938 - nuc_center: 0.8284 - val_loss: 0.3349 - val_binary_accuracy: 0.9862 - val_nuc_interior: 0.9695 - val_nuc_partition: 0.1997 - val_nuc_center: 0.8666
# Epoch 42/75
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3626 - binary_accuracy: 0.9778 - nuc_interior: 0.9486 - nuc_partition: 0.5348 - nuc_center: 0.8357 - val_loss: 0.3361 - val_binary_accuracy: 0.9860 - val_nuc_interior: 0.9679 - val_nuc_partition: 0.2010 - val_nuc_center: 0.8589
# Epoch 43/75
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3606 - binary_accuracy: 0.9783 - nuc_interior: 0.9469 - nuc_partition: 0.5251 - nuc_center: 0.8329 - val_loss: 0.3368 - val_binary_accuracy: 0.9856 - val_nuc_interior: 0.9662 - val_nuc_partition: 0.1912 - val_nuc_center: 0.8573
# Epoch 44/75
# 27/27 [==============================] - 9s 341ms/step - loss: 0.3635 - binary_accuracy: 0.9777 - nuc_interior: 0.9476 - nuc_partition: 0.4937 - nuc_center: 0.8304 - val_loss: 0.3359 - val_binary_accuracy: 0.9858 - val_nuc_interior: 0.9694 - val_nuc_partition: 0.1915 - val_nuc_center: 0.8675
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 45/75
# 27/27 [==============================] - 8s 312ms/step - loss: 0.3751 - binary_accuracy: 0.9776 - nuc_interior: 0.9491 - nuc_partition: 0.5794 - nuc_center: 0.8404 - val_loss: 0.3369 - val_binary_accuracy: 0.9859 - val_nuc_interior: 0.9643 - val_nuc_partition: 0.2047 - val_nuc_center: 0.8523
# Epoch 46/75
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3655 - binary_accuracy: 0.9772 - nuc_interior: 0.9442 - nuc_partition: 0.4376 - nuc_center: 0.8197 - val_loss: 0.3350 - val_binary_accuracy: 0.9860 - val_nuc_interior: 0.9681 - val_nuc_partition: 0.1846 - val_nuc_center: 0.8573
# Epoch 47/75
# 27/27 [==============================] - 9s 316ms/step - loss: 0.3668 - binary_accuracy: 0.9777 - nuc_interior: 0.9450 - nuc_partition: 0.5075 - nuc_center: 0.8285 - val_loss: 0.3367 - val_binary_accuracy: 0.9858 - val_nuc_interior: 0.9694 - val_nuc_partition: 0.2029 - val_nuc_center: 0.8657
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.

# %%
plot_model_history(history.history, window=slice(None, None))
# Out:
# <ggplot: (-9223363304867530720)>

# %%
pred_model = model

# %%
def inference_data(ids):
    mask = np.in1d(index, ids)
    Xi, Yi = X[mask], Y_target[mask]
    loader = imgaug_utils.InMemoryDataLoader(Xi, Yi, augmentation=None, processor=pre_network_processor)
    gen = keras_generator.BaseDataGenerator(loader.ids, loader.load, batch_size=len(Xi), shuffle=True)
    return gen[0]

inf_ids = [
    'a102535b0e88374bea4a1cfd9ee7cb3822ff54f4ab2a9845d428ec22f9ee2288',
    '0ea221716cf13710214dcd331a61cea48308c3940df1d28cfc7fd817c83714e1',
    '07fb37aafa6626608af90c1e18f6a743f29b6b233d2e427dcd1102df6a916cf5',
    '20b20ab049372d184c705acebe7af026d3580f5fd5a72ed796e3622e1685af2f',
    '5afb7932e9c7328f4fb1d7a8166a3699d6cdc5192b93758a75e9956f1513c5a3',
    '8efed2e62c919e6d70a2ab548b1a33014877fe8a23f177ef25a9dee25ffe8842',
    '547ef286ee5f4e5dce533e982e6992ada67b7d727fdd3cfa6576f24c631a7ae6',
    'c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932',
    'cb4df20a83b2f38b394c67f1d9d4aef29f9794d5345da3576318374ec3a11490',
    '6fe2df6de1d962b90146c822bcefc84d0d3d6926fdfbacd3acdc9de830ee5622'
]
X_pred, Y_true = inference_data(inf_ids)
X_pred.shape, Y_true.shape
# Out:
# ((63, 256, 256, 1), (63, 256, 256, 3))

# %%
#pred_batch = train_batches
X_pred, Y_true = test_generator[1]
#X_pred, Y_true = train_generator[0]

# %%
Y_pred = pred_model.predict(X_pred)

# %%
X_pred.shape, Y_pred.shape, Y_true.shape
# Out:
# ((32, 256, 256, 1), (32, 256, 256, 3), (32, 256, 256, 3))

# %%
X_pred.min(), X_pred.max()
# Out:
# (-0.58835554, 5.947034)

# %%
Y_pred.min(), Y_pred.max()
# Out:
# (0.26898405, 0.99999595)

# %%
# plt.hist(Y_pred.ravel(), bins=248)
# ax = plt.gca()
# ax.set_yscale('symlog')
# None

# %%
train_classes
# Out:
# ['nuc_interior', 'nuc_partition', 'nuc_center']

# %%
from skimage import exposure
y_chs = [0, 1, 2]
assert len(y_chs) == 3
viz_idx = np.random.choice(np.arange(len(X_pred)), replace=False, size=min(5, len(X_pred)))
#viz_idx = [0, 1, 2, 3, 4, 5]
#viz_idx = [0, 1, 2]
for i in viz_idx:
    images = []
    images += [exposure.rescale_intensity(X_pred[i, ..., 0], out_range=np.uint8).astype(np.uint8)]
    images += [exposure.rescale_intensity(Y_true[i][..., y_chs], out_range=np.uint8).astype(np.uint8)]
    images += [np.stack([
        exposure.rescale_intensity(Y_pred[i][..., yi], out_range=np.uint8).astype(np.uint8)
        for yi in y_chs
    ], -1)]
    visualize.display_images(images, size=50, cols=3)

# %%
y_chs = [0, 1, 2]
for i in [0, 1, 2, 3, 4, 5]:
    images = []
    images += [X_pred[i, ..., 0]]
    images += [Y_true[i, ..., ch] for ch in y_chs]
    images += [Y_pred[i, ..., ch] for ch in y_chs]
    visualize.display_images(images, size=32, cols=2*len(y_chs)+1)
